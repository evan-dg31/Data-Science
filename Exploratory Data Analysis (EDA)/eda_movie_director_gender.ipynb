# %% [markdown]
# #### EDA Movie Director Gender

# %% [markdown]
# EDA on how many female directors vs male. What's the average tomatometer_rating and audience_rating by director_gender. How many movies is directed by a female vs male director

# %%
import pandas as pd
from matplotlib import pyplot as plt 

df = pd.read_csv("../Data/movie_reviews.csv")

# %%
df.head()
df.info()
df['director_gender'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_title         166 non-null    object
#  1   rating              166 non-null    object
#  2   genre               166 non-null    object
#  3   in_theaters_date    166 non-null    object
#  4   movie_info          166 non-null    object
#  5   directors           166 non-null    object
#  6   director_gender     166 non-null    object
#  7   tomatometer_rating  166 non-null    int64
#  8   audience_rating     166 non-null    int64
#  9   critics_consensus   147 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 13.1+ KB
# director_gender
# male      134
# female     32
# Name: count, dtype: int64

# %% [markdown]
# There are 134 male directores compared to 32 female directors.

# %%
movie_counts = df['director_gender'].value_counts()
print(movie_counts)
# Out:
# director_gender
# male      134
# female     32
# Name: count, dtype: int64

# %%
avg_ratings = df.groupby('director_gender')[['tomatometer_rating', 'audience_rating']].mean()
print(avg_ratings)
# Out:
#                  tomatometer_rating  audience_rating
# director_gender
# female                    71.218750        61.281250
# male                      65.835821        66.962687

# %%
avg_ratings.plot(kind='bar', title='Average Ratings by Director Gender')
plt.ylabel('Average Rating')
plt.show()
